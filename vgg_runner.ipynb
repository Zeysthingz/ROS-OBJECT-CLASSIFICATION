# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
ls
# Out:
# dataset_loader.py  __pycache__/   train_config.yml  vgg16/
# __init__.py        test_model.py  train.py          vgg.py

# %%
cd gdrive/
# Out:
# [Errno 2] No such file or directory: 'gdrive/'
# /content/gdrive/MyDrive/LeoTask

# %%
 cd MyDrive/
# Out:
# [Errno 2] No such file or directory: 'MyDrive/'
# /content/gdrive/MyDrive/LeoTask

# %%
# !mkdir LeoTask

# %%
! git clone https://github.com/Erendrgnl/TrafficSign-Classification-ROS2-Yolov3.git
# Out:
# Cloning into 'TrafficSign-Classification-ROS2-Yolov3'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 89 (delta 34), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (89/89), done.

# %%
cd LeoTask
# Out:
# /content/gdrive/MyDrive/LeoTask

# %%
pip install -U PyYAML
# Out:
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (3.13)
# Collecting PyYAML
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 4.4 MB/s
# Installing collected packages: PyYAML
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-6.0

# %%
pip uninstall torch
# Out:
# WARNING: Skipping torch as it is not installed.

# %%
pip uninstall torchvision
# Out:
# Found existing installation: torchvision 0.11.3
# Uninstalling torchvision-0.11.3:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/torchvision-0.11.3.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/torchvision.libs/libcudart.d9bbffd7.so.10.2
#     /usr/local/lib/python3.7/dist-packages/torchvision.libs/libjpeg.ceea7512.so.62
#     /usr/local/lib/python3.7/dist-packages/torchvision.libs/libnvjpeg.23816019.so.10
#     /usr/local/lib/python3.7/dist-packages/torchvision.libs/libpng16.7f72a3c5.so.16
#     /usr/local/lib/python3.7/dist-packages/torchvision.libs/libz.1328edc3.so.1
#     /usr/local/lib/python3.7/dist-packages/torchvision/*
# Proceed (y/n)?   ERROR: Operation cancelled by user

# %%
# !pip3 install torch==1.2.0+cu92 torchvision==0.4.0+cu92 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.2.0+cu92
#   Downloading https://download.pytorch.org/whl/cu92/torch-1.2.0%2Bcu92-cp37-cp37m-manylinux1_x86_64.whl (663.1 MB)
#      |████████████████████████████████| 663.1 MB 1.6 kB/s
# Collecting torchvision==0.4.0+cu92
#   Downloading https://download.pytorch.org/whl/cu92/torchvision-0.4.0%2Bcu92-cp37-cp37m-manylinux1_x86_64.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 43.3 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.2.0+cu92) (1.21.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchvision==0.4.0+cu92) (1.15.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.4.0+cu92) (7.1.2)
# Installing collected packages: torch, torchvision
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.11.0 requires torch==1.10.0, but you have torch 1.2.0+cu92 which is incompatible.
# torchaudio 0.10.0+cu111 requires torch==1.10.0, but you have torch 1.2.0+cu92 which is incompatible.
# Successfully installed torch-1.2.0+cu92 torchvision-0.4.0+cu92

# %%
pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.2.0+cu92)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (0.4.0+cu92)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.7/dist-packages (0.10.0+cu111)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch) (1.21.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.15.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision) (7.1.2)
# Collecting torchaudio
#   Downloading torchaudio-0.10.2-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 4.2 MB/s
#   Downloading torchaudio-0.10.1-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 37.6 MB/s
#   Downloading torchaudio-0.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 34.4 MB/s
#   Downloading torchaudio-0.9.1-cp37-cp37m-manylinux1_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 35.0 MB/s
#   Downloading torchaudio-0.9.0-cp37-cp37m-manylinux1_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 30.3 MB/s
#   Downloading torchaudio-0.8.1-cp37-cp37m-manylinux1_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 36.4 MB/s
#   Downloading torchaudio-0.8.0-cp37-cp37m-manylinux1_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 36.9 MB/s
#   Downloading torchaudio-0.7.2-cp37-cp37m-manylinux1_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 30.0 MB/s
#   Downloading torchaudio-0.7.0-cp37-cp37m-manylinux1_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 27.6 MB/s
#   Downloading torchaudio-0.6.0-cp37-cp37m-manylinux1_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 21.0 MB/s
#   Downloading torchaudio-0.5.1-cp37-cp37m-manylinux1_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 34.0 MB/s
#   Downloading torchaudio-0.5.0-cp37-cp37m-manylinux1_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 35.4 MB/s
#   Downloading torchaudio-0.4.0-cp37-cp37m-manylinux1_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 36.2 MB/s
#   Downloading torchaudio-0.3.2-cp37-cp37m-manylinux1_x86_64.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 32.7 MB/s
#   Downloading torchaudio-0.3.1-cp37-cp37m-manylinux1_x86_64.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 33.0 MB/s
#   Downloading torchaudio-0.3.0-cp37-cp37m-manylinux1_x86_64.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 36.1 MB/s
# Installing collected packages: torchaudio
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.10.0+cu111
#     Uninstalling torchaudio-0.10.0+cu111:
#       Successfully uninstalled torchaudio-0.10.0+cu111
# Successfully installed torchaudio-0.3.0

# %%
import torchvision  
print(torchvision.__version__)
# Out:
# 0.4.0+cu92

# %%
pip install --upgrade torchvision
# Out:
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (0.11.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.21.5)
# Requirement already satisfied: torch==1.10.2 in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.10.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision) (7.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.10.2->torchvision) (3.10.0.2)

# %%
# !python train.py
# Out:
# Found 2 class : ['go', 'stop']
# 1911 images found belonging to the class go
# 2666 images found belonging to the class stop
# Found 2 class : ['go', 'stop']
# 239 images found belonging to the class go
# 334 images found belonging to the class stop
# [epoch 0] mean loss 0.308: 100% 72/72 [02:22<00:00,  1.98s/it]
# 100% 573/573 [03:44<00:00,  2.55it/s]
# [epoch 1] mean loss 0.162: 100% 72/72 [02:19<00:00,  1.94s/it]
# 100% 573/573 [00:18<00:00, 31.29it/s]
# [epoch 2] mean loss 0.133: 100% 72/72 [02:19<00:00,  1.94s/it]
# 100% 573/573 [00:18<00:00, 31.27it/s]
# [epoch 3] mean loss 0.119: 100% 72/72 [02:19<00:00,  1.94s/it]
# 100% 573/573 [00:18<00:00, 31.17it/s]
# [epoch 4] mean loss 0.099: 100% 72/72 [02:18<00:00,  1.93s/it]
# 100% 573/573 [00:18<00:00, 31.45it/s]
# [epoch 5] mean loss 0.083: 100% 72/72 [02:19<00:00,  1.94s/it]
# 100% 573/573 [00:18<00:00, 31.43it/s]
# [epoch 6] mean loss 0.079: 100% 72/72 [02:17<00:00,  1.91s/it]
# 100% 573/573 [00:18<00:00, 31.44it/s]
# [epoch 7] mean loss 0.082: 100% 72/72 [02:19<00:00,  1.93s/it]
# 100% 573/573 [00:18<00:00, 31.55it/s]
# [epoch 8] mean loss 0.083: 100% 72/72 [02:18<00:00,  1.92s/it]
# 100% 573/573 [00:18<00:00, 31.31it/s]
# [epoch 9] mean loss 0.078: 100% 72/72 [02:18<00:00,  1.93s/it]
# 100% 573/573 [00:18<00:00, 31.20it/s]
# [epoch 10] mean loss 0.072: 100% 72/72 [02:18<00:00,  1.92s/it]
# 100% 573/573 [00:18<00:00, 30.98it/s]
# [epoch 11] mean loss 0.072: 100% 72/72 [02:19<00:00,  1.93s/it]
# 100% 573/573 [00:18<00:00, 30.99it/s]
# [epoch 12] mean loss 0.076: 100% 72/72 [02:18<00:00,  1.93s/it]
# 100% 573/573 [00:18<00:00, 31.15it/s]
# [epoch 13] mean loss 0.069: 100% 72/72 [02:18<00:00,  1.93s/it]
# 100% 573/573 [00:18<00:00, 31.25it/s]
# [epoch 14] mean loss 0.072: 100% 72/72 [02:17<00:00,  1.91s/it]
# 100% 573/573 [00:18<00:00, 31.27it/s]
# <Figure size 640x480 with 2 Axes>

# %%
# !python test_model.py
# Out:
# Found 2 class : ['go', 'stop']
# 241 images found belonging to the class go
# 335 images found belonging to the class stop
# Precision 0.975
# Recall 0.970954356846473
# f1_score 0.9729729729729729
# test_acc 0.9774305555555556
